# %%
import pandas as pd

df = pd.read_csv('./data/processed/processed_stock_data.csv', index_col=0, parse_dates=True)
display(df.head())

import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(df.index, df['Close'], marker='o', linestyle='-')
plt.title('Fechamento Diário da Ação')
plt.xlabel('Data')
plt.ylabel('Preço de Fechamento (USD)')
plt.grid()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
#               Open      High     Low   Close     Volume
# 2024-03-14  196.95  197.7480  192.12  193.43  4102202.0
# 2024-03-15  191.99  193.0573  190.70  191.07  8828184.0
# 2024-03-18  191.70  193.2300  190.32  191.69  5410562.0
# 2024-03-19  191.49  193.5800  190.28  193.34  5317341.0
# 2024-03-20  192.87  193.9800  191.31  193.96  3238643.0
